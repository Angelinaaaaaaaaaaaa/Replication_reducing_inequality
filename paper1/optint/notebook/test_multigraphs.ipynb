# %% [markdown]
# Following example shows:
# - complete graph with size 5 where the optimal intervention is on last 2 nodes
# - number of instances=3
# - number of runs for e
# - ach method=10
# - number of time steps=10
#
# To replicate the plots (**Fig. 5, Supplemntary Fig. 4-7**) in the paper: change the above parameters according to the paper

# %%
from argparse import Namespace
import numpy as np
import matplotlib.pyplot as plt

from optint.data import synthetic_instance, gen_dag
from optint.run import run
from optint.visualize import *
import os

# %% [markdown]
# ### Generate synthetic instances

# %%
seed = 1
np.random.seed(seed)

# generate problem instantiation
nnodes = 5
sigma_square = np.ones(nnodes)
DAG_type = 'complete'

num_instances = 3
a_size = 2

problems = []
graph = gen_dag(nnodes=nnodes, DAG_type=DAG_type)
for _ in range(num_instances):
	problem = synthetic_instance(
		nnodes=nnodes, 
		DAG_type=DAG_type,
		std=True,
		sigma_square=sigma_square, 
		a_size=a_size,
		a_target_nodes=[i+(nnodes-max(a_size,2)) for i in range(a_size)], 
		prefix_DAG=graph
		)
	problems.append(problem)

# %%
draw(
	problem.DAG, 
	colored_set = set(i for i in range(problem.nnodes) if problem.a_target[i]!=0), 
	affected_set=set().union(*[problem.DAG.descendants_of(i) for i in range(problem.nnodes) if problem.a_target[i]!=0]),
	)
# Out:
# there are no undirected edges
# plotting...

# %% [markdown]
# ### Run 5 methods

# %%
# options for testing
opts = Namespace(n=1, T=10, W=0, R=10, time=False)

# %%
acqs = ['greedy', 'maxv','cv', 'civ', 'civ']
measure = [None, None, None, 'unif', 'ow']
known_variance = [False, True, True, True, True]
name = ['greedy', 'maxv', 'cv', 'civ', 'civow']


MSEs = []
As = []
Probs = []
Times = []
for i in range(num_instances):
	problem = problems[i]

	A = {}
	Prob = {}
	Time = {}
	
	opts.active = False
	A['passive'], Prob['passive'] = run(problem, opts)

	opts.active = True
	for a in range(len(acqs)):
		opts.acq = acqs[a]
		opts.measure = measure[a]
		opts.known_noise = known_variance[a]
		A[name[a]], Prob[name[a]] = run(problem, opts)

	print(f'Graph {i+1}')

	As.append(A)
	Probs.append(Prob)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 175.31it/s]
# 100%|██████████| 10/10 [00:00<00:00, 16.37it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.97it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.71it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.03it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.12it/s]
# Graph 1
# 100%|██████████| 10/10 [00:00<00:00, 250.01it/s]
# 100%|██████████| 10/10 [00:00<00:00, 15.28it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.48it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.58it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.98it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.34it/s]
# Graph 2
# 100%|██████████| 10/10 [00:00<00:00, 285.38it/s]
# 100%|██████████| 10/10 [00:00<00:00, 14.49it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.07it/s]
# 100%|██████████| 10/10 [00:01<00:00,  8.97it/s]
# 100%|██████████| 10/10 [00:01<00:00,  9.54it/s]
# 100%|██████████| 10/10 [00:00<00:00, 10.52it/s]
# Graph 3

# %% [markdown]
# ### Plot results

# %%
mu_MSEs = []
for i in range(num_instances):
    Prob = Probs[i]
    problem = problems[i]
    mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']}
    for r in range(opts.R):
        for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']:
            mse = []
            for prob in Prob[k][r]:
                errs = abs(np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target) - problem.a_target)
                mse.append(np.linalg.norm(np.concatenate(errs))**2)
            mu_mses[k].append(mse)
    mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF']
markers = ['^', 'o', 'o', 'o', 's', 's']
linestyles = ['--','--','--', '--','-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']):
    mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
    std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
    plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
    plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||a_t^*-a^*||_2^2$ (log scale)')
plt.title(f'square distance to target mean')
plt.tight_layout()

# plt.savefig(f'results/figures/mse-int-mean_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

save_dir1 = "results/figures"
filename1 = f"mse-int-mean_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf"
full_path1 = os.path.join(save_dir1, filename1)
os.makedirs(save_dir1, exist_ok=True)
plt.savefig(full_path1)
print(f"Plot saved as: {full_path1}")
# Out:
# Plot saved as: results/figures\mse-int-mean_complete-5-2-randtarget_new5.pdf

# %%
mu_MSEs = []
for i in range(num_instances):
	Prob = Probs[i]
	problem = problems[i]
	mu_mses = {k:[] for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']}
	for r in range(opts.R):
		for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']:
			mse = []
			for prob in Prob[k][r]:
				errs = abs(np.dot(problem.A,np.dot(np.eye(problem.nnodes)-np.array(prob['mean']),problem.mu_target)) - problem.mu_target)
				mse.append(np.linalg.norm(np.concatenate(errs)) / np.linalg.norm(problem.mu_target))
			mu_mses[k].append(mse)
	mu_MSEs.append(mu_mses)

plt.clf()
fig, ax = plt.subplots(1,1,figsize=(5.6,3.8))
plt.rcParams.update({'font.size': 12})

plt.yscale('log')

labels = ['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW']
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF']
markers = ['^', 'o', 'o', 'o', 's', 's']
linestyles = ['--','--','--', '--','-', '-']
for i, k in enumerate(['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']):
	mean = np.array([np.array(mu_MSEs[i][k]).mean(axis=0) for i in range(num_instances)]).mean(axis=0)
	std = np.array([np.array(mu_MSEs[i][k]).std(axis=0) for i in range(num_instances)]).mean(axis=0)
	plt.plot(range(opts.T), mean, label=labels[i], linewidth=2, color=colors[i], marker=markers[i], markersize=0, linestyle=linestyles[i])
	plt.fill_between(range(opts.T), mean - std, mean + std, alpha=.2, color=colors[i])

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)
plt.ylim(0.01,1)

plt.legend(loc='upper right')
plt.xlabel(r'time step $t$')
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
plt.title(f'relative distance to target mean')
plt.tight_layout()

# plt.savefig(f'results/figures/relative-rmse_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

save_dir2 = "results/figures"
filename2 = f"relative-rmse_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf"
full_path2 = os.path.join(save_dir2, filename2)
os.makedirs(save_dir2, exist_ok=True)
plt.plot([1, 2, 3], [6, 5, 4])  # Example plot; replace with your actual plot
plt.savefig(full_path2)
print(f"Plot saved as: {full_path2}")
# Out:
# Plot saved as: results/figures\relative-rmse_complete-5-2-randtarget_new5.pdf

# %%
plt.clf()
fig, ax = plt.subplots(1,1,figsize=(4,4))
plt.rcParams.update({'font.size': 12})

data = []
for k in ['passive', 'greedy', 'maxv', 'cv', 'civ', 'civow']:
	data.append([np.array(mu_MSEs[i][k]).mean(axis=0)[-1] for i in range(num_instances)])
bplots = plt.boxplot(data, labels=['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW'], patch_artist=False);

# fill with colors
colors = ['#069AF3', '#9ACD32', 'black', 'grey', 'orange', '#C79FEF']

for patch, color in zip(bplots['boxes'], colors):
	# patch.set_facecolor(color)
	patch.set(color=color, linewidth=1.5)
	
for line, color in zip(bplots['medians'], colors):
	# patch.set_facecolor(color)
	line.set(color=color, linewidth=1.5)

ax.spines.right.set_visible(False)
ax.spines.top.set_visible(False)

plt.legend(loc='upper right')
plt.xticks(rotation=45)
plt.ylabel(r'$||\mu_t^*-\mu^*||_2~/~||\mu^*||_2$ (log scale)')
plt.title(f'time step {opts.T}')
plt.yscale('log')
plt.tight_layout()

# plt.savefig(f'figures/rebut/relative-err-lastround_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf')

save_dir3 = "results/figures"
filename3 = f"relative-err-lastround_{DAG_type}-{nnodes}-{a_size}-randtarget_new5.pdf"
full_path3 = os.path.join(save_dir3, filename3)
os.makedirs(save_dir3, exist_ok=True)
plt.plot([1, 2, 3], [3, 5, 7])  # Example plot; replace with your actual plot
plt.savefig(full_path3)
print(f"Plot saved as: {full_path3}")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13264\2423803938.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bplots = plt.boxplot(data, labels=['Random', 'Greedy', 'MaxV', 'CV', 'CIV', 'CIV-OW'], patch_artist=False);
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13264\2423803938.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='upper right')
# Plot saved as: figures/rebut\relative-err-lastround_complete-5-2-randtarget_new5.pdf
